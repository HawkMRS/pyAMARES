# %%
import pyAMARES

pyAMARES.__version__
# Out:
# /home/xujia/miniconda3/envs/py312/lib/python3.12/site-packages/numpy/_core/getlimits.py:552: UserWarning: Signature b'\x00\xd0\xcc\xcc\xcc\xcc\xcc\xcc\xfb\xbf\x00\x00\x00\x00\x00\x00' for <class 'numpy.longdouble'> does not match any known type: falling back to type probe function.
# This warnings indicates broken support for the dtype!
#   machar = _get_machar(dtype)
# '0.3.34dev'

# %% [markdown]
# # Prior Knowledge Spreadsheet for pyAMARES
# **[Try this tutorial on Google Colab!](https://colab.research.google.com/drive/1mVx7avSBsynBnYk_VVMeJWsAgfq4iR0G)**
#
#
#
# - PyAMARES imports prior knowledge from spreadsheets to use as initial values and constraints for fitting MRS data based on the AMARES model function.
# - The prior knowledge spreadsheet can be in CSV or MS Excel (xlsx) format.
# - In this spreadsheet:
#     - The upper half defines the initial values.
#     - The lower half specifies the fitting constraints.
#     - The parameters for a given peak are defined in a column of the spreadsheet.
# - `pyAMARES.initialize_FID` can be used to load and preview the prior knowledge spreadsheet.
# - **Comments**: Lines starting with `#` can be used to add comments to the prior knowledge spreadsheet. In the CSV format, comments cannot be added to the first rows. However, this limitation does not apply to the Excel (xlsx) format.

# %% [markdown]
# - A simple example of peak parameter of a singlet

# %%
single_obj = pyAMARES.initialize_FID(
    fid=None, priorknowledgefile="singlet.csv", preview=True
)
# Out:
# [AMARES | WARNING] Fid is None! Creating unity array instead.
#                      Peak_A       Peak_B
# Index
# Initial Values          NaN          NaN
# amplitude              10.0          8.0
# chemicalshift           5.0         -3.0
# linewidth             100.0         50.0
# phase                   0.0          0.0
# g                       0.0          0.0
# Bounds                  NaN          NaN
# amplitude              (0,          (0,
# chemicalshift           NaN          NaN
# linewidth               (0,          (0,
# phase           (-180, 180)  (-180, 180)
# g                     (0,1)        (0,1)

# %% [markdown]
# - **Initial Fitting Parameter**
#     - The parsed initial prior knowledge is converted into an lmfit Parameter object.
#     - Each parameter includes initial values, minimum and maximum limits, and a `vary` flag that indicates whether it is fixed during the fitting process.
#     - In addition to editing the input spreadsheet, fitting parameters can also be manually modified in the code.
#     - **Refinement of Fitted Parameters**: The fitted parameters (not shown in this tutorial) will be returned in the same format and can be refined for subsequent rounds of fitting.

# %% [markdown]
# ## Spreadsheet Format
#
# - **Index Column**: Always use the terms `amplitude`, `chemicalshift`, `linewidth`, `phase`, and `g` as index labels in the spreadsheet for both initial values and constraints
#
# - **Setup Constraints**:
#    - Constraints are set using brackets. For example, `(-180, 180)` indicates a range from -180 to 180.
#    - If only a lower bound is needed, omit the second half of the bracket. For example, `(0,` specifies a range of 0 and above.
#    - **(New after version 0.3.4)** If only a single value is specified in a constraint cell,
#    the corresponding parameter is fixed and will not be fitted.
#
# - **Physical Units**:
#     - In the spreadsheet, the `amplitude` and `g` values are unitless. `chemicalshift` is measured in ppm, `linewidth` in Hz, and `phase` in degrees.

# %% [markdown]
# ## Setting Up J-coupling Splitted Multiplets: An Example of In Vivo 31P MRS of the Human Brain at 7T
#
# - **Peak Name Suffix**:
#     - To set up a multiplet, designate the main sublet peak using ASCII letters, and define other sublets by adding numeric suffixes to the main peak name. For instance, the triplet for $\beta$-ATP is labeled `BATP`, `BATP2`, and `BATP3`.
#     - Therefore, the numbers are not allowed in other peak names.
#     - Similarly, the doublet for $\gamma$-ATP is labeled `GATP` and `GATP2`.
#
# - **Constraints for Multiplets**:
#     - Parameters can be constrained using mathematical expressions, which is especially useful for multiplet setups.
#     - Multiplets separated by J-coupling share parameters like phase and linewidth (LW). Constraints for these can be linked to the main peak name; for example, `BATP` in the `LW` and `phase` rows.
#     - The `chemicalshifts` of sublets can be constrained relative to the main peak using its peak name and the J-coupling constants. For example, `BATP-15Hz` indicates the `chemicalshift` is set 15 Hz lower than that of $\beta$-ATP. If ppm is used, it will be converted to Hz using the `MHz` argument.
#     - The `amplitude` of sublets can be related to the main peak. For instance, with $\beta$-ATP as a triplet having 1:2:1 amplitude ratios, the amplitude constraints for the sublets could be set as `BATP/2`. Similarly, for $\gamma$-ATP, where two sublets have a 1:1 amplitude ratio, the amplitude can be set as `GATP`.
#     - Since the prior knowledge dataset spreadsheet is parsed from left to right, the peak that will be mathematically constrained to it must always be put to the left of the peaks that will be constrained. For example, for the multiplets, the main peak, such as `BATP`, will always be put to the left of `BATP2` or `BATP3`, whose amplitude constraints will be fixed as `BATP/2`.

# %%
multiplet_obj = pyAMARES.initialize_FID(
    fid=None, priorknowledgefile="example_human_brain_31P_7T.csv", preview=True
)
# Out:
# [AMARES | WARNING] Fid is None! Creating unity array instead.
#                                                                 BATP  \
# Index
# Initial Values                                                   NaN
# amplitude                                                       1.41
# chemicalshift                                                 -16.15
# linewidth                                                  58.119999
# phase                                                            0.0
# g                                                                0.0
# Bounds                                                           NaN
# amplitude                                                       (0,
# chemicalshift                                        (-16.30,-16.00)
# linewidth                                           (54.335, 61.911)
# phase                                                    (-180, 180)
# g                                                              (0,1)
#  # 2024/06/24 In Ren et al, the chemical shift ...               NaN
# # So, increase the chemical shift range                          NaN
# NaN                                                              NaN
#
#                                                                BATP2  \
# Index
# Initial Values                                                   NaN
# amplitude                                                     BATP/2
# chemicalshift                                              BATP-15Hz
# linewidth                                                       BATP
# phase                                                           BATP
# g                                                                0.0
# Bounds                                                           NaN
# amplitude                                                       (0,
# chemicalshift                                        (-16.30,-16.00)
# linewidth                                           (54.335, 61.911)
# phase                                                    (-180, 180)
# g                                                              (0,1)
#  # 2024/06/24 In Ren et al, the chemical shift ...               NaN
# # So, increase the chemical shift range                          NaN
# NaN                                                              NaN
#
#                                                                BATP3  \
# Index
# Initial Values                                                   NaN
# amplitude                                                     BATP/2
# chemicalshift                                              BATP+15Hz
# linewidth                                                       BATP
# phase                                                           BATP
# g                                                                0.0
# Bounds                                                           NaN
# amplitude                                                       (0,
# chemicalshift                                        (-16.30,-16.00)
# linewidth                                           (54.335, 61.911)
# phase                                                    (-180, 180)
# g                                                              (0,1)
#  # 2024/06/24 In Ren et al, the chemical shift ...               NaN
# # So, increase the chemical shift range                          NaN
# NaN                                                              NaN
#
#                                                                 AATP  \
# Index
# Initial Values                                                   NaN
# amplitude                                                      1.545
# chemicalshift                                                  -7.49
# linewidth                                                  32.279999
# phase                                                           BATP
# g                                                                0.0
# Bounds                                                           NaN
# amplitude                                                       (0,
# chemicalshift                                          (-7.72,-7.42)
# linewidth                                           (31.226, 33.327)
# phase                                                    (-180, 180)
# g                                                              (0,1)
#  # 2024/06/24 In Ren et al, the chemical shift ...               NaN
# # So, increase the chemical shift range                          NaN
# NaN                                                              NaN
#
#                                                                AATP2  \
# Index
# Initial Values                                                   NaN
# amplitude                                                       AATP
# chemicalshift                                              AATP-16Hz
# linewidth                                                       AATP
# phase                                                           BATP
# g                                                                0.0
# Bounds                                                           NaN
# amplitude                                                       (0,
# chemicalshift                                          (-7.72,-7.42)
# linewidth                                           (31.226, 33.327)
# phase                                                    (-180, 180)
# g                                                              (0,1)
#  # 2024/06/24 In Ren et al, the chemical shift ...               NaN
# # So, increase the chemical shift range                          NaN
# NaN                                                              NaN
#
#                                                                 GATP  \
# Index
# Initial Values                                                   NaN
# amplitude                                                        1.5
# chemicalshift                                                  -2.46
# linewidth                                                      39.02
# phase                                                           BATP
# g                                                                0.0
# Bounds                                                           NaN
# amplitude                                                       (0,
# chemicalshift                                          (-2.65,-2.39)
# linewidth                                           (36.892, 41.157)
# phase                                                    (-180, 180)
# g                                                              (0,1)
#  # 2024/06/24 In Ren et al, the chemical shift ...               NaN
# # So, increase the chemical shift range                          NaN
# NaN                                                              NaN
#
#                                                                GATP2  \
# Index
# Initial Values                                                   NaN
# amplitude                                                       GATP
# chemicalshift                                              GATP-16Hz
# linewidth                                                       GATP
# phase                                                           BATP
# g                                                                0.0
# Bounds                                                           NaN
# amplitude                                                       (0,
# chemicalshift                                          (-2.65,-2.39)
# linewidth                                           (36.892, 41.157)
# phase                                                    (-180, 180)
# g                                                              (0,1)
#  # 2024/06/24 In Ren et al, the chemical shift ...               NaN
# # So, increase the chemical shift range                          NaN
# NaN                                                              NaN
#
#                                                                 UDPG  \
# Index
# Initial Values                                                   NaN
# amplitude                                                       0.08
# chemicalshift                                                  -9.72
# linewidth                                                  32.369999
# phase                                                           BATP
# g                                                                0.0
# Bounds                                                           NaN
# amplitude                                                       (0,
# chemicalshift                                          (-9.76,-9.68)
# linewidth                                           (29.125, 35.619)
# phase                                                    (-180, 180)
# g                                                              (0,1)
#  # 2024/06/24 In Ren et al, the chemical shift ...               NaN
# # So, increase the chemical shift range                          NaN
# NaN                                                              NaN
#
#                                                                  NAD  \
# Index
# Initial Values                                                   NaN
# amplitude                                                       0.41
# chemicalshift                                                  -8.25
# linewidth                                                  40.490002
# phase                                                           BATP
# g                                                                0.0
# Bounds                                                           NaN
# amplitude                                                       (0,
# chemicalshift                                          (-8.25,-8.17)
# linewidth                                           (34.823, 46.155)
# phase                                                    (-180, 180)
# g                                                              (0,1)
#  # 2024/06/24 In Ren et al, the chemical shift ...               NaN
# # So, increase the chemical shift range                          NaN
# NaN                                                              NaN
#
#                                                                 PCr  \
# Index
# Initial Values                                                  NaN
# amplitude                                                      4.37
# chemicalshift                                                   0.0
# linewidth                                                     15.41
# phase                                                          BATP
# g                                                               0.0
# Bounds                                                          NaN
# amplitude                                                      (0,
# chemicalshift                                           (-0.5, 0.5)
# linewidth                                           (13.21, 17.603)
# phase                                                   (-180, 180)
# g                                                             (0,1)
#  # 2024/06/24 In Ren et al, the chemical shift ...              NaN
# # So, increase the chemical shift range                         NaN
# NaN                                                             NaN
#
#                                                                  GPC  \
# Index
# Initial Values                                                   NaN
# amplitude                                                       1.32
# chemicalshift                                                   2.95
# linewidth                                                  19.959999
# phase                                                           BATP
# g                                                                0.0
# Bounds                                                           NaN
# amplitude                                                       (0,
# chemicalshift                                            (2.94,2.96)
# linewidth                                           (18.557, 21.359)
# phase                                                    (-180, 180)
# g                                                              (0,1)
#  # 2024/06/24 In Ren et al, the chemical shift ...               NaN
# # So, increase the chemical shift range                          NaN
# NaN                                                              NaN
#
#                                                                  GPE  \
# Index
# Initial Values                                                   NaN
# amplitude                                                        0.8
# chemicalshift                                                    3.5
# linewidth                                                       19.1
# phase                                                           BATP
# g                                                                0.0
# Bounds                                                           NaN
# amplitude                                                       (0,
# chemicalshift                                            (3.49,3.51)
# linewidth                                           (17.348, 20.849)
# phase                                                    (-180, 180)
# g                                                              (0,1)
#  # 2024/06/24 In Ren et al, the chemical shift ...               NaN
# # So, increase the chemical shift range                          NaN
# NaN                                                              NaN
#
#                                                                  Pin  \
# Index
# Initial Values                                                   NaN
# amplitude                                                       0.85
# chemicalshift                                                   4.82
# linewidth                                                  21.040001
# phase                                                           BATP
# g                                                                0.0
# Bounds                                                           NaN
# amplitude                                                       (0,
# chemicalshift                                            (4.81,4.83)
# linewidth                                           (19.353, 22.727)
# phase                                                    (-180, 180)
# g                                                              (0,1)
#  # 2024/06/24 In Ren et al, the chemical shift ...               NaN
# # So, increase the chemical shift range                          NaN
# NaN                                                              NaN
#
#                                                                  Pex  \
# Index
# Initial Values                                                   NaN
# amplitude                                                        0.3
# chemicalshift                                                   5.24
# linewidth                                                      30.91
# phase                                                           BATP
# g                                                                0.0
# Bounds                                                           NaN
# amplitude                                                       (0,
# chemicalshift                                            (5.19,5.29)
# linewidth                                           (22.091, 39.725)
# phase                                                    (-180, 180)
# g                                                              (0,1)
#  # 2024/06/24 In Ren et al, the chemical shift ...               NaN
# # So, increase the chemical shift range                          NaN
# NaN                                                              NaN
#
#                                                                  PC  \
# Index
# Initial Values                                                  NaN
# amplitude                                                       0.3
# chemicalshift                                                  6.24
# linewidth                                                 19.959999
# phase                                                          BATP
# g                                                               0.0
# Bounds                                                          NaN
# amplitude                                                      (0,
# chemicalshift                                           (6.22,6.26)
# linewidth                                           (15.756, 24.16)
# phase                                                   (-180, 180)
# g                                                             (0,1)
#  # 2024/06/24 In Ren et al, the chemical shift ...              NaN
# # So, increase the chemical shift range                         NaN
# NaN                                                             NaN
#
#                                                                   PE
# Index
# Initial Values                                                   NaN
# amplitude                                                       2.27
# chemicalshift                                                   6.76
# linewidth                                                  22.629999
# phase                                                           BATP
# g                                                                0.0
# Bounds                                                           NaN
# amplitude                                                       (0,
# chemicalshift                                            (6.71,6.81)
# linewidth                                           (20.658, 24.605)
# phase                                                    (-180, 180)
# g                                                              (0,1)
#  # 2024/06/24 In Ren et al, the chemical shift ...               NaN
# # So, increase the chemical shift range                          NaN
# NaN                                                              NaN

# %% [markdown]
# - **Initial Fitting Parameter**

# %%
multiplet_obj.initialParams
# Out:
# Parameters([('ak_BATP', <Parameter 'ak_BATP', value=np.float32(1.41), bounds=[np.float64(0.0):inf]>), ('freq_BATP', <Parameter 'freq_BATP', value=np.float32(-1938.0), bounds=[np.float64(-1955.9998779296875):np.float64(-1920.0)]>), ('dk_BATP', <Parameter 'dk_BATP', value=np.float32(182.58937), bounds=[np.float64(170.6984405517578):np.float64(194.4991455078125)]>), ('phi_BATP', <Parameter 'phi_BATP', value=np.float64(0.0), bounds=[np.float64(-3.1415927410125732):np.float64(3.1415927410125732)]>), ('g_BATP', <Parameter 'g_BATP', value=0.0 (fixed), bounds=[np.float64(0.0):np.float64(1.0)]>), ('ak_BATP2', <Parameter 'ak_BATP2', value=0.7049999833106995, bounds=[np.float64(0.0):inf], expr='ak_BATP/2'>), ('freq_BATP2', <Parameter 'freq_BATP2', value=-1953.0, bounds=[np.float64(-1955.9998779296875):np.float64(-1920.0)], expr='freq_BATP-15'>), ('dk_BATP2', <Parameter 'dk_BATP2', value=182.58937072753906, bounds=[np.float64(170.6984405517578):np.float64(194.4991455078125)], expr='dk_BATP'>), ('phi_BATP2', <Parameter 'phi_BATP2', value=0.0, bounds=[np.float64(-3.1415927410125732):np.float64(3.1415927410125732)], expr='phi_BATP'>), ('g_BATP2', <Parameter 'g_BATP2', value=0.0 (fixed), bounds=[np.float64(0.0):np.float64(1.0)]>), ('ak_BATP3', <Parameter 'ak_BATP3', value=0.7049999833106995, bounds=[np.float64(0.0):inf], expr='ak_BATP/2'>), ('freq_BATP3', <Parameter 'freq_BATP3', value=-1923.0, bounds=[np.float64(-1955.9998779296875):np.float64(-1920.0)], expr='freq_BATP+15'>), ('dk_BATP3', <Parameter 'dk_BATP3', value=182.58937072753906, bounds=[np.float64(170.6984405517578):np.float64(194.4991455078125)], expr='dk_BATP'>), ('phi_BATP3', <Parameter 'phi_BATP3', value=0.0, bounds=[np.float64(-3.1415927410125732):np.float64(3.1415927410125732)], expr='phi_BATP'>), ('g_BATP3', <Parameter 'g_BATP3', value=0.0 (fixed), bounds=[np.float64(0.0):np.float64(1.0)]>), ('ak_AATP', <Parameter 'ak_AATP', value=np.float32(1.545), bounds=[np.float64(0.0):inf]>), ('freq_AATP', <Parameter 'freq_AATP', value=np.float32(-898.8), bounds=[np.float64(-926.3999633789062):np.float64(-890.4000244140625)]>), ('dk_AATP', <Parameter 'dk_AATP', value=np.float32(101.41061), bounds=[np.float64(98.09937286376953):np.float64(104.69985961914062)]>), ('phi_AATP', <Parameter 'phi_AATP', value=0.0, bounds=[np.float64(-3.1415927410125732):np.float64(3.1415927410125732)], expr='phi_BATP'>), ('g_AATP', <Parameter 'g_AATP', value=0.0 (fixed), bounds=[np.float64(0.0):np.float64(1.0)]>), ('ak_AATP2', <Parameter 'ak_AATP2', value=1.5449999570846558, bounds=[np.float64(0.0):inf], expr='ak_AATP'>), ('freq_AATP2', <Parameter 'freq_AATP2', value=-914.7999877929688, bounds=[np.float64(-926.3999633789062):np.float64(-890.4000244140625)], expr='freq_AATP-16'>), ('dk_AATP2', <Parameter 'dk_AATP2', value=101.41060638427734, bounds=[np.float64(98.09937286376953):np.float64(104.69985961914062)], expr='dk_AATP'>), ('phi_AATP2', <Parameter 'phi_AATP2', value=0.0, bounds=[np.float64(-3.1415927410125732):np.float64(3.1415927410125732)], expr='phi_BATP'>), ('g_AATP2', <Parameter 'g_AATP2', value=0.0 (fixed), bounds=[np.float64(0.0):np.float64(1.0)]>), ('ak_GATP', <Parameter 'ak_GATP', value=np.float32(1.5), bounds=[np.float64(0.0):inf]>), ('freq_GATP', <Parameter 'freq_GATP', value=np.float32(-295.2), bounds=[np.float64(-318.0):np.float64(-286.8000183105469)]>), ('dk_GATP', <Parameter 'dk_GATP', value=np.float32(122.58495), bounds=[np.float64(115.8996353149414):np.float64(129.2985382080078)]>), ('phi_GATP', <Parameter 'phi_GATP', value=0.0, bounds=[np.float64(-3.1415927410125732):np.float64(3.1415927410125732)], expr='phi_BATP'>), ('g_GATP', <Parameter 'g_GATP', value=0.0 (fixed), bounds=[np.float64(0.0):np.float64(1.0)]>), ('ak_GATP2', <Parameter 'ak_GATP2', value=1.5, bounds=[np.float64(0.0):inf], expr='ak_GATP'>), ('freq_GATP2', <Parameter 'freq_GATP2', value=-311.20001220703125, bounds=[np.float64(-318.0):np.float64(-286.8000183105469)], expr='freq_GATP-16'>), ('dk_GATP2', <Parameter 'dk_GATP2', v ...

# %% [markdown]
# ## Use a Single Value in the Constraint Cell to Fix the Corresponding Parameter (New after version 0.3.4)

# %%
FixExampleObj = pyAMARES.initialize_FID(
    fid=None, priorknowledgefile="Table1.csv", preview=True
)
# Out:
# [AMARES | WARNING] Fid is None! Creating unity array instead.
#                         Cr_a          Cr_b         Glu         Glx  \
# Index
# Initial Values           NaN           NaN         NaN         NaN
# amplitude                2.5          16.0         5.0         6.0
# chemicalshift       3.021495          3.92    2.346443    3.762504
# linewidth                3.0          14.3        19.0         3.5
# phase                    0.0           0.0         0.0         0.0
# g                        0.0           0.0         0.0         0.0
# Bounds                   NaN           NaN         NaN         NaN
# amplitude         (2.4, 2.6)  (15.0, 17.0)  (4.5, 5.5)  (5.4, 6.6)
# chemicalshift   (3.02, 3.03)          3.92        2.35        3.75
# linewidth           (12, 15)          20.0        20.0     (22,25)
# phase                    0.0           0.0         0.0         0.0
# g                        0.0           0.0         0.0         0.0
#
#                        Ins          Ins2         Ins_b        NAA_a  \
# Index
# Initial Values         NaN           NaN           NaN          NaN
# amplitude             2.55           Ins           1.0          4.0
# chemicalshift     3.523662      3.620098      4.042568     1.984933
# linewidth              2.6           7.9           2.6          2.2
# phase                  0.0           0.0           0.0          0.0
# g                      0.0           0.0           0.0          0.0
# Bounds                 NaN           NaN           NaN          NaN
# amplitude       (2.3, 2.8)    (2.3, 2.8)    (0.9, 1.1)   (3.6, 4.4)
# chemicalshift         3.52  (3.61, 3.62)  (4.03, 4.04)  (2.0, 2.01)
# linewidth             20.0          20.0          20.0     (10, 18)
# phase                  0.0           0.0           0.0        180.0
# g                      0.0           0.0           0.0          0.0
#
#                          NAA          NAA2           Tau          Tau2
# Index
# Initial Values           NaN           NaN           NaN           NaN
# amplitude               5.25           NAA           7.0           Tau
# chemicalshift       2.499841      2.659735      3.259837      3.418482
# linewidth               13.0           NAA           3.5           Tau
# phase                    0.0           0.0         180.0         180.0
# g                        0.0           0.0           0.0           0.0
# Bounds                   NaN           NaN           NaN           NaN
# amplitude         (5.0, 5.5)    (5.0, 5.5)    (6.7, 7.3)    (6.7, 7.3)
# chemicalshift   (2.51, 2.52)  (2.66, 2.67)  (3.41, 3.42)  (3.24, 3.25)
# linewidth       (18.0, 22.0)  (18.0, 22.0)          20.0          20.0
# phase                    0.0           0.0         180.0         180.0
# g                        0.0           0.0           0.0           0.0

# %% [markdown]
# - In this prior knowledge spreadsheet, the phases are fixed at either 0 or 180, as determined by the single-value constraint cells. As shown in the initial fitting parameters below, all phase parameters are fixed (`vary=False`) and will not be fitted.

# %%
loadedpk_pd = pyAMARES.parameters_to_dataframe(FixExampleObj.initialParams)
loadedpk_pd.loc[loadedpk_pd.name.str.startswith("phi")]
# Out:
#          name     value  min  max   vary  expr
# 3    phi_Cr_a  0.000000 -inf  inf  False  None
# 8    phi_Cr_b  0.000000 -inf  inf  False  None
# 13    phi_Glu  0.000000 -inf  inf  False  None
# 18    phi_Glx  0.000000 -inf  inf  False  None
# 23    phi_Ins  0.000000 -inf  inf  False  None
# 28   phi_Ins2  0.000000 -inf  inf  False  None
# 33  phi_Ins_b  0.000000 -inf  inf  False  None
# 38  phi_NAA_a  3.141593 -inf  inf  False  None
# 43    phi_NAA  0.000000 -inf  inf  False  None
# 48   phi_NAA2  0.000000 -inf  inf  False  None
# 53    phi_Tau  3.141593 -inf  inf  False  None
# 58   phi_Tau2  3.141593 -inf  inf  False  None
